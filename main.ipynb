# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
ROOT_DIR = '/content/drive/MyDrive/OSIRV'

# %%
# !ls {ROOT_DIR}
# Out:
# classes.txt		    content_processed.zip  models_data.zip  OSIRV.ipynb
# content_processed_rgbd.zip  info.json		   models_yaml.zip  yolo.zip

# %%
# %%capture
# !unzip "/content/drive/MyDrive/OSIRV/models_data.zip" -d "/content"
# !unzip "/content/drive/MyDrive/OSIRV/models_yaml.zip" -d "/content"

# %%
# %%capture
# !unzip "/content/drive/MyDrive/OSIRV/yolo.zip" -d "/content/yolo"

# %%
# !mkdir /content/datasets

# %%
# %%capture
# !unzip "/content/drive/MyDrive/OSIRV/content_processed_rgbd.zip" -d "/content/datasets"

# %%
# %%capture
# !unzip "/content/drive/MyDrive/OSIRV/content_processed.zip" -d "/content/datasets"

# %%
import shutil
#shutil.rmtree('/content/yolo', ignore_errors=True)

# %%
# !pip install tifffile

# %%
# !pip uninstall albumentations -y
# Out:
# Found existing installation: albumentations 2.0.5
# Uninstalling albumentations-2.0.5:
#   Successfully uninstalled albumentations-2.0.5

# %%
# %cd yolo
# !pip install -e .
# %cd ../
# !pip install supervision flash-attn
# !pip show ultralytics
import torch
# Out:
# /content/yolo
# Obtaining file:///content/yolo
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 129.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 100.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 23.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.1 MB/s eta 0:00:00
# ...

# %%
# !pip install supervision flash-attn ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 57.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.8/978.8 kB 65.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 133.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 103.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# RGBD
model = YOLO('./models_yaml/RGBD/yolov12s.yaml')

results = model.train(data='./models_data/RGBD/data.yaml', epochs=100, imgsz=640, batch=64, augment=False, pretrained = False)
#results = model.train(data='./data_depth.yaml', epochs=100, batch = 64, ch = 1)
# Out:
# New https://pypi.org/project/ultralytics/8.3.111 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.110 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
import shutil
shutil.make_archive('models', 'zip', './runs')
# Out:
# '/content/models.zip'

# %%
# RGB

model = YOLO('./models_yaml/RGB/yolov12s.yaml')

results = model.train(data='./models_data/RGB/data.yaml', epochs=100, imgsz=640, batch=64, augment=False, pretrained = False)
# Out:
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
# Depth
model = YOLO('./models_yaml/Depth/yolov12s.yaml')
results = model.train(data='./models_data/Depth/data.yaml', epochs=100, batch = 64, imgsz = 640, augment = False,  pretrained = False)
# Out:
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
import shutil

#shutil.rmtree('./runs/detect/train2', ignore_errors=True)
#shutil.rmtree('./runs', ignore_errors=True)

# %%
#shutil.rmtree('./datasets', ignore_errors=True)

# %%
shutil.make_archive('yolo', 'zip', 'yolo')
# Out:
# '/content/yolo.zip'

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					   PR_curve.png		  val_batch0_pred.jpg
# confusion_matrix_normalized.png			   R_curve.png		  val_batch1_labels.jpg
# confusion_matrix.png				   results.csv		  val_batch1_pred.jpg
# events.out.tfevents.1741956024.e65bb2344c0f.481.0  results.png		  val_batch2_labels.jpg
# F1_curve.png					   train_batch0.jpg	  val_batch2_pred.jpg
# labels_correlogram.jpg				   train_batch1.jpg	  weights
# labels.jpg					   train_batch2.jpg
# P_curve.png					   val_batch0_labels.jpg

# %%
from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train2/confusion_matrix.png', width=1000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-a74fddc60089> in <cell line: 0>()
#       1 from IPython.display import Image
#       2
# ----> 3 Image(filename=f'{HOME}/runs/detect/train2/confusion_matrix.png', width=1000)
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.11/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
from IPython.display import Image

Image(filename=f'{HOME}/runs/detect/train2/results.png', width=1000)

# %%
import supervision as sv

ds = sv.DetectionDataset.from_yolo(
    images_directory_path="datasets/content/RGBD/val/images",
    annotations_directory_path="datasets/content/RGBD/val/labels",
    data_yaml_path=f"data_rgbd.yaml"
)

ds.classes
# Out:
# ['chair',
#  'table',
#  'pillow',
#  'desk',
#  'sofa_chair',
#  'cabinet',
#  'lamp',
#  'sofa',
#  'door',
#  'bed',
#  'box',
#  'garbage_bin',
#  'monitor',
#  'shelf',
#  'counter',
#  'computer',
#  'endtable',
#  'sink',
#  'bookshelf',
#  'night_stand',
#  'drawer',
#  'dresser',
#  'paper',
#  'painting',
#  'keyboard',
#  'coffee_table',
#  'cpu',
#  'ottoman',
#  'tv',
#  'picture',
#  'stool',
#  'recycle_bin',
#  'whiteboard',
#  'bench',
#  'toilet',
#  'mirror',
#  'fridge',
#  'printer',
#  'curtain',
#  'bottle',
#  'laptop',
#  'vanity',
#  'towel',
#  'plant',
#  'books',
#  'book',
#  'cloth',
#  'microwave',
#  'bag',
#  'dresser_mirror',
#  'cup',
#  'stove',
#  'mouse',
#  'bowl',
#  'back_pack',
#  'bathtub',
#  'cart',
#  'tray',
#  'person',
#  'rack',
#  'plate',
#  'container',
#  'telephone',
#  'mug',
#  'poster',
#  'podium',
#  'tissue',
#  'blinds',
#  'tv_stand',
#  'speaker',
#  'cubby',
#  'scanner',
#  'bulletin_board',
#  'projector',
# ...

# %%
from supervision.metrics import MeanAveragePrecision

model = YOLO(f'/{HOME}/runs/detect/train2/weights/best.pt')

predictions = []
targets = []

for _, image, target in ds:
    results = model(image, verbose=False)[0]
    detections = sv.Detections.from_ultralytics(results)

    predictions.append(detections)
    targets.append(target)

map = MeanAveragePrecision().update(predictions, targets).compute()

# %%
print("mAP 50:95", map.map50_95)
print("mAP 50", map.map50)
print("mAP 75", map.map75)
# Out:
# mAP 50:95 0.23841067350566406
# mAP 50 0.3138311422891146
# mAP 75 0.26666403672744443

# %%
import random

i = random.randint(0, len(ds))

image_path, image, target = ds[i]
print(image_path)

results = model(image, verbose=False)[0]
detections = sv.Detections.from_ultralytics(results).with_nms()

box_annotator = sv.BoxAnnotator()
label_annotator = sv.LabelAnnotator()

annotated_image = image.copy()
annotated_image = box_annotator.annotate(scene=annotated_image, detections=detections)
annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

sv.plot_image(annotated_image)
# Out:
# datasets/content/RGBD/val/images/02263.png
